# %% [markdown]
# <a href="https://colab.research.google.com/github/luizhenriquefonseca/Exercicios-para-Estruturas-de-Dados/blob/main/Conhe%C3%A7a_o_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
I = [1,1,2,3,2,1,3,2,1,2,2]
print(I)
cnj = set(I)
print(cnj)
I = list(cnj)
print(I)
# Out:
# [1, 1, 2, 3, 2, 1, 3, 2, 1, 2, 2]
# {1, 2, 3}
# [1, 2, 3]
